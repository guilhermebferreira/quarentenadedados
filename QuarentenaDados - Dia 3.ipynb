# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
imdb = pd.read_csv('dados/movie_metadata.csv')
imdb.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
imdb['color'].value_counts()
# Out:
# Color               4815
#  Black and White     209
# Name: color, dtype: int64

# %%
imdb['color'].value_counts(normalize=True)
# Out:
# Color               0.9584
#  Black and White    0.0416
# Name: color, dtype: float64

# %%
imdb['director_name'].value_counts().head(30)
# Out:
# Steven Spielberg        26
# Woody Allen             22
# Clint Eastwood          20
# Martin Scorsese         20
# Ridley Scott            17
# Spike Lee               16
# Tim Burton              16
# Steven Soderbergh       16
# Renny Harlin            15
# Oliver Stone            14
# Robert Rodriguez        13
# Joel Schumacher         13
# Barry Levinson          13
# Sam Raimi               13
# Ron Howard              13
# Michael Bay             13
# John Carpenter          13
# Robert Zemeckis         13
# Wes Craven              12
# Tony Scott              12
# Richard Donner          12
# Peter Jackson           12
# Brian De Palma          12
# Kevin Smith             12
# Shawn Levy              12
# Rob Reiner              11
# Francis Ford Coppola    11
# Richard Linklater       11
# Rob Cohen               11
# Chris Columbus          11
# Name: director_name, dtype: int64

# %%
imdb[imdb['director_name'].str.contains("Cohen", na=False)]
# Out:
#       color    director_name  num_critic_for_reviews  duration  \
# 72    Color        Rob Cohen                   264.0     112.0
# 100   Color        Rob Cohen                   187.0     106.0
# 164   Color        Rob Cohen                   145.0     121.0
# 395   Color        Rob Cohen                   187.0     106.0
# 493   Color        Rob Cohen                    61.0     114.0
# 585   Color        Rob Cohen                   191.0     132.0
# 829   Color        Rob Cohen                    60.0     103.0
# 1202  Color       Etan Cohen                   173.0     107.0
# 1332  Color        Rob Cohen                   187.0     106.0
# 1461  Color        Rob Cohen                   211.0     101.0
# 2640  Color        Rob Cohen                   102.0     106.0
# 3898  Color        Rob Cohen                   149.0      91.0
# 4090  Color   Peter M. Cohen                    48.0      82.0
# 4990  Color        Jem Cohen                    12.0     111.0
# ...

# %%
imdb['num_critic_for_reviews']
# Out:
# 0       723.0
# 1       302.0
# 2       602.0
# 3       813.0
# 4         NaN
#         ...
# 5038      1.0
# 5039     43.0
# 5040     13.0
# 5041     14.0
# 5042     43.0
# Name: num_critic_for_reviews, Length: 5043, dtype: float64

# %%
imdb['num_critic_for_reviews'].describe()
# Out:
# count    4993.000000
# mean      140.194272
# std       121.601675
# min         1.000000
# 25%        50.000000
# 50%       110.000000
# 75%       195.000000
# max       813.000000
# Name: num_critic_for_reviews, dtype: float64

# %%
imdb['num_critic_for_reviews'].plot(kind='hist')

# %%
imdb['gross'].plot(kind='hist')

# %%
sns.distplot(imdb['gross'])

# %%
#sample retorna amostras aleatorias do dataset
imdb.sort_values('gross', ascending=False).sample(10)
# Out:
#       color    director_name  num_critic_for_reviews  duration  \
# 2453  Color      Hal Needham                    40.0      99.0
# 719   Color       Peter Weir                   213.0     103.0
# 1879  Color         Ronny Yu                   273.0      97.0
# 2819  Color          Ang Lee                   357.0     134.0
# 3921  Color   Allison Anders                    51.0     110.0
# 1981  Color  Kimberly Peirce                   143.0     112.0
# 2976  Color   Dean Israelite                   177.0     106.0
# 3377  Color       Wes Craven                   109.0     107.0
# 215   Color   John McTiernan                    85.0     102.0
# 2382  Color   Emile Ardolino                    10.0      92.0
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 2453                    379.0                   251.0        Michael Beck
# 719                     608.0                   576.0       Noah Emmerich
# ...

# %% [markdown]
# ## Perguntas Gerais
#
# - aventura tem nota melhor que comédia?
# - diretor com mais filmes tem nota melhor?
# - as respostas são específicas para a nossa amostra ou para o mundo?
# - quais correlações existem entre os dados?
# - budget x gross (orçamento x faturamento)

# %%
sns.distplot(imdb['budget'])

# %%
imdb['budget'].describe()
# Out:
# count    4.551000e+03
# mean     3.975262e+07
# std      2.061149e+08
# min      2.180000e+02
# 25%      6.000000e+06
# 50%      2.000000e+07
# 75%      4.500000e+07
# max      1.221550e+10
# Name: budget, dtype: float64

# %%
#remover NaN da coluna color
color_or_bw = imdb.query("color in ['Color', ' Black and White']")
len(color_or_bw)
# Out:
# 5024

# %%
#gambiarra para receber 0 ou 1 se for verdadeiro

color_or_bw['color_0_ou_1'] = (color_or_bw['color'] =='Color') * 1 
color_or_bw.head()
# Out:
# /home/guilherme/.local/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 5  Color     Andrew Stanton                   462.0     132.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# ...

# %%
color_or_bw['color_0_ou_1'].value_counts()
# Out:
# 1    4815
# 0     209
# Name: color_0_ou_1, dtype: int64

# %%
# Filmes coloridos vendem mais do que preto e branco?
sns.scatterplot(data=color_or_bw, x='color_0_ou_1', y='gross')

# %%
color_or_bw.groupby('color').mean()['gross']
# Out:
# color
#  Black and White    3.245702e+07
# Color               4.902619e+07
# Name: gross, dtype: float64

# %%
color_or_bw.groupby('color').mean()['imdb_score']
# Out:
# color
#  Black and White    7.227273
# Color               6.409533
# Name: imdb_score, dtype: float64

# %%
color_or_bw.groupby('color').median()['imdb_score']
# Out:
# color
#  Black and White    7.4
# Color               6.5
# Name: imdb_score, dtype: float64

# %%
sns.scatterplot(data = imdb[['budget', 'gross']].dropna(), )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-f15c5a880a9d> in <module>
# ----> 1 sns.scatterplot(imdb[['budget', 'gross']].dropna())
#
# ~/.local/lib/python3.6/site-packages/seaborn/relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#    1400         x_bins=x_bins, y_bins=y_bins,
#    1401         estimator=estimator, ci=ci, n_boot=n_boot,
# -> 1402         alpha=alpha, x_jitter=x_jitter, y_jitter=y_jitter, legend=legend,
#    1403     )
#    1404
#
# ...

# %%
### Desafio 1:
- boxplot de media do imdb_score do colorido e do preto e branco
